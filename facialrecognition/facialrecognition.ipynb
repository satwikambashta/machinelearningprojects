# %%
# !pip install opencv-python
# Out:
# ...
#   Obtaining dependency information for opencv-python from https://files.pythonhosted.org/packages/c7/ec/9dabb6a9abfdebb3c45b0cc52dec901caafef2b2c7e7d6a839ed86d81e91/opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl.metadata
# ...
#    ---------------------------------------- 0.0/38.6 MB ? eta -:--:--
#    ---------------------------------------- 0.1/38.6 MB 3.4 MB/s eta 0:00:12
#    ---------------------------------------- 0.1/38.6 MB 3.4 MB/s eta 0:00:12
#    ---------------------------------------- 0.1/38.6 MB 573.4 kB/s eta 0:01:08
#    ---------------------------------------- 0.2/38.6 MB 1.3 MB/s eta 0:00:31
#     --------------------------------------- 0.5/38.6 MB 2.3 MB/s eta 0:00:17
#     --------------------------------------- 0.7/38.6 MB 2.7 MB/s eta 0:00:15
#     --------------------------------------- 0.8/38.6 MB 2.8 MB/s eta 0:00:14
#    - -------------------------------------- 1.0/38.6 MB 2.9 MB/s eta 0:00:13
# ...

# %%
# !pip install face_recognition
# Out:
# ...
#      ---------------------------------------- 0.0/100.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/100.1 MB ? eta -:--:--
#      ---------------------------------------- 0.1/100.1 MB 2.0 MB/s eta 0:00:51
#      ---------------------------------------- 0.3/100.1 MB 2.6 MB/s eta 0:00:38
#      ---------------------------------------- 0.5/100.1 MB 3.3 MB/s eta 0:00:31
#      ---------------------------------------- 0.7/100.1 MB 3.3 MB/s eta 0:00:30
#      ---------------------------------------- 0.9/100.1 MB 3.6 MB/s eta 0:00:28
#      ---------------------------------------- 1.2/100.1 MB 4.1 MB/s eta 0:00:25
#       --------------------------------------- 1.5/100.1 MB 4.4 MB/s eta 0:00:23
#       --------------------------------------- 2.0/100.1 MB 5.2 MB/s eta 0:00:19
#       --------------------------------------- 2.5/100.1 MB 5.7 MB/s eta 0:00:18
#      - -------------------------------------- 2.9/100.1 MB 5.9 MB/s eta 0:00:17
# ...

# %%
import cv2

# %%
import face_recognition
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import face_recognition
#
# ModuleNotFoundError: No module named 'face_recognition'
